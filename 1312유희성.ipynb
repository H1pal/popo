# %%
print('eco'*3)
# Out:
# ecoecoeco

# %%
print(2**10)
print(False)
# Out:
# 1024
# False

# %%
print('Hellow'>='Hello ')
# Out:
# True

# %%
he = 5
he = input('first: ')
na = input('second: ')
print(he+na)
# Out:
# 30
